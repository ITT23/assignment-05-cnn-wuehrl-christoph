# %% [markdown]
# The first part is unchanged to have the same conditions for all tests

# %%
import cv2
import json
from matplotlib import pyplot as plt
import numpy as np
import os
import random

# import a lot of things from keras:
# sequential model
from keras.models import Sequential

# layers
from keras.layers import Input, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, RandomFlip, RandomRotation, RandomContrast, RandomBrightness

# loss function
from keras.metrics import categorical_crossentropy

# callback functions
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

# convert data to categorial vector representation
from keras.utils import to_categorical

# nice progress bar for loading data
from tqdm.notebook import tqdm

# helper function for train/test split
from sklearn.model_selection import train_test_split

# import confusion matrix helper function
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# import pre-trained model
from keras.applications.vgg16 import VGG16

# include only those gestures
CONDITIONS = ['like', 'stop']

# image size
IMG_SIZE = 64
SIZE = (IMG_SIZE, IMG_SIZE)

# number of color channels we want to use
# set to 1 to convert to grayscale
# set to 3 to use color images
COLOR_CHANNELS = 3

# %% [markdown]
# ## helper function to load and parse annotations

# %%
annotations = dict()

for condition in CONDITIONS:
    with open(f'_annotations/{condition}.json') as f:
        annotations[condition] = json.load(f)

# %% [markdown]
# ## helper function to pre-process images (color channel conversion and resizing)

# %%
def preprocess_image(img):
    if COLOR_CHANNELS == 1:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_resized = cv2.resize(img, SIZE)
    return img_resized

# %% [markdown]
# ## load images and annotations

# %%
images = [] # stores actual image data
labels = [] # stores labels (as integer - because this is what our network needs)
label_names = [] # maps label ints to their actual categories so we can understand predictions later

# loop over all conditions
# loop over all files in the condition's directory
# read the image and corresponding annotation
# crop image to the region of interest
# preprocess image
# store preprocessed image and label in corresponding lists
for condition in CONDITIONS:
    for filename in tqdm(os.listdir(condition)):
        # extract unique ID from file name
        UID = filename.split('.')[0]
        img = cv2.imread(f'{condition}/{filename}')
        
        # get annotation from the dict we loaded earlier
        try:
            annotation = annotations[condition][UID]
        except Exception as e:
            print(e)
            continue
        
        # iterate over all hands annotated in the image
        for i, bbox in enumerate(annotation['bboxes']):
            # annotated bounding boxes are in the range from 0 to 1
            # therefore we have to scale them to the image size
            x1 = int(bbox[0] * img.shape[1])
            y1 = int(bbox[1] * img.shape[0])
            w = int(bbox[2] * img.shape[1])
            h = int(bbox[3] * img.shape[0])
            x2 = x1 + w
            y2 = y1 + h
            
            # crop image to the bounding box and apply pre-processing
            crop = img[y1:y2, x1:x2]
            preprocessed = preprocess_image(crop)
            
            # get the annotated hand's label
            # if we have not seen this label yet, add it to the list of labels
            label = annotation['labels'][i]
            if label not in label_names:
                label_names.append(label)
            
            label_index = label_names.index(label)
            
            images.append(preprocessed)
            labels.append(label_index)
# Out:
# ...
#   0%|          | 0/250 [00:00<?, ?it/s]

# %% [markdown]
# ## let's have a look at one of the images

# %%
plt.imshow(random.sample(images, 1)[0])

# %% [markdown]
# ## split data set into train and test
#
# x is for the actual data, y is for the label (this is convention)

# %%
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

print(len(X_train))
print(len(X_test))
print(len(y_train))
print(len(y_test))
# Out:
# 512
# 128
# 512
# 128

# %% [markdown]
# ## transform data sets into a format compatible with our neural network
#
# image data has to be a numpy array with following dimensions: [image_id, y_axis, x_axis, color_channels]
#
# furthermore, scale all values to a range of 0 to 1
#
# training data has to be converted to a categorial vector ("one hot"):
#
# [3] --> [0, 0, 0, 1, 0, ..., 0]

# %%
X_train = np.array(X_train).astype('float32')
X_train = X_train / 255.

X_test = np.array(X_test).astype('float32')
X_test = X_test / 255.

y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

train_label = y_train_one_hot
test_label = y_test_one_hot

X_train = X_train.reshape(-1, IMG_SIZE, IMG_SIZE, COLOR_CHANNELS)
X_test = X_test.reshape(-1, IMG_SIZE, IMG_SIZE, COLOR_CHANNELS)

print(X_train.shape, X_test.shape, train_label.shape, test_label.shape)
# Out:
# (512, 64, 64, 3) (128, 64, 64, 3) (512, 3) (128, 3)

# %% [markdown]
# # Methode to define the model with different parameters

# %%
def define_model(function_parameter):
    # variables for hyperparameters
    batch_size = 8
    epochs = 50
    num_classes = len(label_names)
    activation = 'relu'
    activation_conv = function_parameter  # LeakyReLU
    layer_count = 2
    num_neurons = 64

    # define model structure
    # with keras, we can use a model's add() function to add layers to the network one by one
    model = Sequential()

    # data augmentation (this can also be done beforehand - but don't augment the test dataset!)
    model.add(RandomFlip('horizontal'))
    model.add(RandomContrast(0.1))
    #model.add(RandomBrightness(0.1))
    #model.add(RandomRotation(0.2))

    # first, we add some convolution layers followed by max pooling
    model.add(Conv2D(64, kernel_size=(9, 9), activation=activation_conv, input_shape=(SIZE[0], SIZE[1], COLOR_CHANNELS), padding='same'))
    model.add(MaxPooling2D(pool_size=(4, 4), padding='same'))

    model.add(Conv2D(32, (5, 5), activation=activation_conv, padding='same'))
    model.add(MaxPooling2D(pool_size=(3, 3), padding='same'))

    model.add(Conv2D(32, (3, 3), activation=activation_conv, padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

    # dropout layers can drop part of the data during each epoch - this prevents overfitting
    model.add(Dropout(0.2))

    # after the convolution layers, we have to flatten the data so it can be fed into fully connected layers
    model.add(Flatten())

    # add some fully connected layers ("Dense")
    for i in range(layer_count - 1):
        model.add(Dense(num_neurons, activation=activation))

    model.add(Dense(num_neurons, activation=activation))

    # for classification, the last layer has to use the softmax activation function, which gives us probabilities for each category
    model.add(Dense(num_classes, activation='softmax'))

    # specify loss function, optimizer and evaluation metrics
    # for classification, categorial crossentropy is used as a loss function
    # use the adam optimizer unless you have a good reason not to
    model.compile(loss=categorical_crossentropy, optimizer="adam", metrics=['accuracy'])

    # define callback functions that react to the model's behavior during training
    # in this example, we reduce the learning rate once we get stuck and early stopping
    # to cancel the training if there are no improvements for a certain amount of epochs
    #reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.0001)
    #stop_early = EarlyStopping(monitor='val_loss', patience=3)
    return model

# %% [markdown]
# # Methode to train the model when it is pre defined

# %%
def train_model(model):
    batch_size = 8
    epochs = 50
    layer_count = 2
    num_neurons = 64
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.0001)
    stop_early = EarlyStopping(monitor='val_loss', patience=3)
    history = model.fit(
        X_train,
        train_label,
        batch_size=batch_size,
        epochs=epochs,
        verbose=1,
        validation_data=(X_test, test_label),
        callbacks=[reduce_lr, stop_early]
    )
    return history

# %% [markdown]
# ## Hyperparameters for the test
# My hyperparameter was the activation function of the convolution kernels:
#
# I selected 5 different functions to train the model. The 5 functions are:
# - ReLu (as described in the lecture it is the most common function today)
# - leakyReLu (is a variant of the ReLu function in which negative values are not set to zero but to a small negative value this helps to avoid "dead neurons" in the ReLu function (source: https://medium.com/mlearning-ai/activation-functions-relu-vs-leaky-relu-b8272dc0b1be date: 9.6.2023))
# - Sigmoid (as described in the lecture this one was often used before the ReLu-function became prevalent)
# - Tanh (according to https://towardsdatascience.com/beginners-guide-to-understanding-convolutional-neural-networks-ae9ed58bb17d (date: 9.6.2023) this function is also often used when dealing with convolution layers)
# - linear (I choose this function to see how a linear function performs in the task, because all other functions are non-linear, but I would expect that it performs much worse because it seems like a nonlinear problem)
#
# I would expect that the linear function performs much worse than the other 4, because it seems like a nonlinear problem. Between the other 4 options I would expect not that much difference because all of them are used or were used to solve such problems. However, I would expect that the leaky ReLu performance better than the ReLu-function because it solves the Problem of dead neurons.

# %% [markdown]
# # ReLu

# %%
model = define_model('relu')
history = train_model(model)
# Out:
# Epoch 1/50
# 64/64 [==============================] - 6s 75ms/step - loss: 1.0636 - accuracy: 0.3887 - val_loss: 1.0454 - val_accuracy: 0.4453 - lr: 0.0010
# Epoch 2/50
# 64/64 [==============================] - 5s 72ms/step - loss: 1.0401 - accuracy: 0.4316 - val_loss: 0.9844 - val_accuracy: 0.5469 - lr: 0.0010
# Epoch 3/50
# 64/64 [==============================] - 5s 71ms/step - loss: 0.8670 - accuracy: 0.6055 - val_loss: 0.7092 - val_accuracy: 0.6328 - lr: 0.0010
# Epoch 4/50
# 64/64 [==============================] - 5s 71ms/step - loss: 0.8025 - accuracy: 0.6367 - val_loss: 0.6550 - val_accuracy: 0.6875 - lr: 0.0010
# Epoch 5/50
# 64/64 [==============================] - 5s 71ms/step - loss: 0.5636 - accuracy: 0.7773 - val_loss: 0.5620 - val_accuracy: 0.7812 - lr: 0.0010
# Epoch 6/50
# 64/64 [==============================] - 5s 75ms/step - loss: 0.4721 - accuracy: 0.8125 - val_loss: 0.3890 - val_accuracy: 0.8516 - lr: 0.0010
# Epoch 7/50
# ...

# %%
# let's have a look at our model
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  random_flip_10 (RandomFlip)  (8, 64, 64, 3)           0
#
#  random_contrast_10 (RandomC  (8, 64, 64, 3)           0
#  ontrast)
#
#  conv2d_30 (Conv2D)          (8, 64, 64, 64)           15616
#
#  max_pooling2d_30 (MaxPoolin  (8, 16, 16, 64)          0
#  g2D)
#
#  conv2d_31 (Conv2D)          (8, 16, 16, 32)           51232
#
#  max_pooling2d_31 (MaxPoolin  (8, 6, 6, 32)            0
#  g2D)
#
#  conv2d_32 (Conv2D)          (8, 6, 6, 32)             9248
#
#  max_pooling2d_32 (MaxPoolin  (8, 3, 3, 32)            0
#  g2D)
#
#  dropout_10 (Dropout)        (8, 3, 3, 32)             0
#
#  flatten_10 (Flatten)        (8, 288)                  0
#
#  dense_30 (Dense)            (8, 64)                   18496
#
#  dense_31 (Dense)            (8, 64)                   4160
#
# ...

# %% [markdown]
# ## Plot accuracy and loss of the training process

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

fig = plt.figure(figsize=(15, 7))
ax = plt.gca()

ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy (Line), Loss (Dashes)')

ax.axhline(1, color='gray')

plt.plot(accuracy, color='blue')
plt.plot(val_accuracy, color='orange')
plt.plot(loss, '--', color='blue', alpha=0.5)
plt.plot(val_loss, '--', color='orange', alpha=0.5)

# %%
# let the model make predictions for our training data
y_predictions = model.predict(X_test)

# to build a confusion matrix, we have to convert it to classifications
# this can be done by using the argmax() function to set the probability to 1 and the rest to 0
y_predictions = np.argmax(y_predictions, axis=1)


# create and plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_predictions)

fig = plt.figure(figsize=(10, 10))

ConfusionMatrixDisplay(conf_matrix, display_labels=label_names).plot(ax=plt.gca())

plt.xticks(rotation=90, ha='center')
pass
# Out:
# 4/4 [==============================] - 0s 56ms/step

# %% [markdown]
# # Leaky ReLu

# %%
model = define_model('LeakyReLU')
history = train_model(model)
# Out:
# Epoch 1/50
# 64/64 [==============================] - 7s 77ms/step - loss: 1.0595 - accuracy: 0.4121 - val_loss: 1.0453 - val_accuracy: 0.4141 - lr: 0.0010
# Epoch 2/50
# 64/64 [==============================] - 5s 74ms/step - loss: 1.0392 - accuracy: 0.4668 - val_loss: 1.0152 - val_accuracy: 0.4453 - lr: 0.0010
# Epoch 3/50
# 64/64 [==============================] - 5s 74ms/step - loss: 0.9468 - accuracy: 0.5371 - val_loss: 0.7827 - val_accuracy: 0.6016 - lr: 0.0010
# Epoch 4/50
# 64/64 [==============================] - 5s 75ms/step - loss: 0.7293 - accuracy: 0.7031 - val_loss: 0.8064 - val_accuracy: 0.6562 - lr: 0.0010
# Epoch 5/50
# 64/64 [==============================] - 5s 74ms/step - loss: 0.5934 - accuracy: 0.7656 - val_loss: 0.4769 - val_accuracy: 0.8203 - lr: 0.0010
# Epoch 6/50
# 64/64 [==============================] - 5s 83ms/step - loss: 0.4554 - accuracy: 0.8477 - val_loss: 0.3441 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 7/50
# ...

# %%
# let's have a look at our model
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  random_flip_11 (RandomFlip)  (8, 64, 64, 3)           0
#
#  random_contrast_11 (RandomC  (8, 64, 64, 3)           0
#  ontrast)
#
#  conv2d_33 (Conv2D)          (8, 64, 64, 64)           15616
#
#  max_pooling2d_33 (MaxPoolin  (8, 16, 16, 64)          0
#  g2D)
#
#  conv2d_34 (Conv2D)          (8, 16, 16, 32)           51232
#
#  max_pooling2d_34 (MaxPoolin  (8, 6, 6, 32)            0
#  g2D)
#
#  conv2d_35 (Conv2D)          (8, 6, 6, 32)             9248
#
#  max_pooling2d_35 (MaxPoolin  (8, 3, 3, 32)            0
#  g2D)
#
#  dropout_11 (Dropout)        (8, 3, 3, 32)             0
#
#  flatten_11 (Flatten)        (8, 288)                  0
#
#  dense_33 (Dense)            (8, 64)                   18496
#
#  dense_34 (Dense)            (8, 64)                   4160
#
# ...

# %% [markdown]
# ## Plot accuracy and loss of the training process

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

fig = plt.figure(figsize=(15, 7))
ax = plt.gca()

ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy (Line), Loss (Dashes)')

ax.axhline(1, color='gray')

plt.plot(accuracy, color='blue')
plt.plot(val_accuracy, color='orange')
plt.plot(loss, '--', color='blue', alpha=0.5)
plt.plot(val_loss, '--', color='orange', alpha=0.5)

# %%
# let the model make predictions for our training data
y_predictions = model.predict(X_test)

# to build a confusion matrix, we have to convert it to classifications
# this can be done by using the argmax() function to set the probability to 1 and the rest to 0
y_predictions = np.argmax(y_predictions, axis=1)


# create and plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_predictions)

fig = plt.figure(figsize=(10, 10))

ConfusionMatrixDisplay(conf_matrix, display_labels=label_names).plot(ax=plt.gca())

plt.xticks(rotation=90, ha='center')
pass
# Out:
# 4/4 [==============================] - 0s 68ms/step

# %% [markdown]
# # Sigmoid

# %%
model = define_model('sigmoid')
history = train_model(model)
# Out:
# Epoch 1/50
# 64/64 [==============================] - 7s 79ms/step - loss: 1.0961 - accuracy: 0.3809 - val_loss: 1.0884 - val_accuracy: 0.3516 - lr: 0.0010
# Epoch 2/50
# 64/64 [==============================] - 5s 73ms/step - loss: 1.0783 - accuracy: 0.4082 - val_loss: 1.0673 - val_accuracy: 0.4219 - lr: 0.0010
# Epoch 3/50
# 64/64 [==============================] - 5s 74ms/step - loss: 1.0518 - accuracy: 0.4141 - val_loss: 1.0511 - val_accuracy: 0.3672 - lr: 0.0010
# Epoch 4/50
# 64/64 [==============================] - 5s 74ms/step - loss: 0.9969 - accuracy: 0.4922 - val_loss: 1.0097 - val_accuracy: 0.4766 - lr: 0.0010
# Epoch 5/50
# 64/64 [==============================] - 5s 73ms/step - loss: 0.9596 - accuracy: 0.5234 - val_loss: 0.9719 - val_accuracy: 0.4844 - lr: 0.0010
# Epoch 6/50
# 64/64 [==============================] - 5s 81ms/step - loss: 0.9292 - accuracy: 0.4941 - val_loss: 0.9898 - val_accuracy: 0.4922 - lr: 0.0010
# Epoch 7/50
# ...

# %%
# let's have a look at our model
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  random_flip_13 (RandomFlip)  (8, 64, 64, 3)           0
#
#  random_contrast_13 (RandomC  (8, 64, 64, 3)           0
#  ontrast)
#
#  conv2d_36 (Conv2D)          (8, 64, 64, 64)           15616
#
#  max_pooling2d_36 (MaxPoolin  (8, 16, 16, 64)          0
#  g2D)
#
#  conv2d_37 (Conv2D)          (8, 16, 16, 32)           51232
#
#  max_pooling2d_37 (MaxPoolin  (8, 6, 6, 32)            0
#  g2D)
#
#  conv2d_38 (Conv2D)          (8, 6, 6, 32)             9248
#
#  max_pooling2d_38 (MaxPoolin  (8, 3, 3, 32)            0
#  g2D)
#
#  dropout_12 (Dropout)        (8, 3, 3, 32)             0
#
#  flatten_12 (Flatten)        (8, 288)                  0
#
#  dense_36 (Dense)            (8, 64)                   18496
#
#  dense_37 (Dense)            (8, 64)                   4160
#
# ...

# %% [markdown]
# ## Plot accuracy and loss of the training process

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

fig = plt.figure(figsize=(15, 7))
ax = plt.gca()

ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy (Line), Loss (Dashes)')

ax.axhline(1, color='gray')

plt.plot(accuracy, color='blue')
plt.plot(val_accuracy, color='orange')
plt.plot(loss, '--', color='blue', alpha=0.5)
plt.plot(val_loss, '--', color='orange', alpha=0.5)

# %%
# let the model make predictions for our training data
y_predictions = model.predict(X_test)

# to build a confusion matrix, we have to convert it to classifications
# this can be done by using the argmax() function to set the probability to 1 and the rest to 0
y_predictions = np.argmax(y_predictions, axis=1)


# create and plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_predictions)

fig = plt.figure(figsize=(10, 10))

ConfusionMatrixDisplay(conf_matrix, display_labels=label_names).plot(ax=plt.gca())

plt.xticks(rotation=90, ha='center')
pass
# Out:
# 4/4 [==============================] - 1s 67ms/step

# %% [markdown]
# # Tanh

# %%
model = define_model('tanh')
history = train_model(model)
# Out:
# Epoch 1/50
# 64/64 [==============================] - 9s 95ms/step - loss: 1.0839 - accuracy: 0.4004 - val_loss: 1.0605 - val_accuracy: 0.4219 - lr: 0.0010
# Epoch 2/50
# 64/64 [==============================] - 6s 92ms/step - loss: 1.0641 - accuracy: 0.4199 - val_loss: 1.1044 - val_accuracy: 0.3516 - lr: 0.0010
# Epoch 3/50
# 64/64 [==============================] - 6s 95ms/step - loss: 0.9336 - accuracy: 0.5352 - val_loss: 0.7471 - val_accuracy: 0.6875 - lr: 0.0010
# Epoch 4/50
# 64/64 [==============================] - 6s 95ms/step - loss: 0.6032 - accuracy: 0.7461 - val_loss: 0.8649 - val_accuracy: 0.6719 - lr: 0.0010
# Epoch 5/50
# 64/64 [==============================] - 6s 98ms/step - loss: 0.4824 - accuracy: 0.8125 - val_loss: 0.2886 - val_accuracy: 0.9141 - lr: 0.0010
# Epoch 6/50
# 64/64 [==============================] - 6s 94ms/step - loss: 0.3717 - accuracy: 0.8691 - val_loss: 0.5229 - val_accuracy: 0.7891 - lr: 0.0010
# Epoch 7/50
# ...

# %%
# let's have a look at our model
model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  random_flip_14 (RandomFlip)  (8, 64, 64, 3)           0
#
#  random_contrast_14 (RandomC  (8, 64, 64, 3)           0
#  ontrast)
#
#  conv2d_39 (Conv2D)          (8, 64, 64, 64)           15616
#
#  max_pooling2d_39 (MaxPoolin  (8, 16, 16, 64)          0
#  g2D)
#
#  conv2d_40 (Conv2D)          (8, 16, 16, 32)           51232
#
#  max_pooling2d_40 (MaxPoolin  (8, 6, 6, 32)            0
#  g2D)
#
#  conv2d_41 (Conv2D)          (8, 6, 6, 32)             9248
#
#  max_pooling2d_41 (MaxPoolin  (8, 3, 3, 32)            0
#  g2D)
#
#  dropout_13 (Dropout)        (8, 3, 3, 32)             0
#
#  flatten_13 (Flatten)        (8, 288)                  0
#
#  dense_39 (Dense)            (8, 64)                   18496
#
#  dense_40 (Dense)            (8, 64)                   4160
#
# ...

# %% [markdown]
# ## Plot accuracy and loss of the training process

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

fig = plt.figure(figsize=(15, 7))
ax = plt.gca()

ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy (Line), Loss (Dashes)')

ax.axhline(1, color='gray')

plt.plot(accuracy, color='blue')
plt.plot(val_accuracy, color='orange')
plt.plot(loss, '--', color='blue', alpha=0.5)
plt.plot(val_loss, '--', color='orange', alpha=0.5)

# %%
# let the model make predictions for our training data
y_predictions = model.predict(X_test)

# to build a confusion matrix, we have to convert it to classifications
# this can be done by using the argmax() function to set the probability to 1 and the rest to 0
y_predictions = np.argmax(y_predictions, axis=1)


# create and plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_predictions)

fig = plt.figure(figsize=(10, 10))

ConfusionMatrixDisplay(conf_matrix, display_labels=label_names).plot(ax=plt.gca())

plt.xticks(rotation=90, ha='center')
pass
# Out:
# 4/4 [==============================] - 0s 64ms/step

# %% [markdown]
# # Linear

# %%
model = define_model('linear')
history = train_model(model)
# Out:
# Epoch 1/50
# 64/64 [==============================] - 7s 81ms/step - loss: 1.1520 - accuracy: 0.3789 - val_loss: 1.1484 - val_accuracy: 0.4219 - lr: 0.0010
# Epoch 2/50
# 64/64 [==============================] - 5s 77ms/step - loss: 1.0941 - accuracy: 0.4219 - val_loss: 1.0298 - val_accuracy: 0.3438 - lr: 0.0010
# Epoch 3/50
# 64/64 [==============================] - 5s 77ms/step - loss: 0.9972 - accuracy: 0.4707 - val_loss: 0.9629 - val_accuracy: 0.5781 - lr: 0.0010
# Epoch 4/50
# 64/64 [==============================] - 5s 79ms/step - loss: 0.8397 - accuracy: 0.5938 - val_loss: 0.7671 - val_accuracy: 0.6719 - lr: 0.0010
# Epoch 5/50
# 64/64 [==============================] - 5s 81ms/step - loss: 0.5876 - accuracy: 0.7402 - val_loss: 0.4843 - val_accuracy: 0.8203 - lr: 0.0010
# Epoch 6/50
# 64/64 [==============================] - 5s 82ms/step - loss: 0.4042 - accuracy: 0.8516 - val_loss: 0.5199 - val_accuracy: 0.8594 - lr: 0.0010
# Epoch 7/50
# ...

# %%
# let's have a look at our model
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  random_flip_15 (RandomFlip)  (8, 64, 64, 3)           0
#
#  random_contrast_15 (RandomC  (8, 64, 64, 3)           0
#  ontrast)
#
#  conv2d_42 (Conv2D)          (8, 64, 64, 64)           15616
#
#  max_pooling2d_42 (MaxPoolin  (8, 16, 16, 64)          0
#  g2D)
#
#  conv2d_43 (Conv2D)          (8, 16, 16, 32)           51232
#
#  max_pooling2d_43 (MaxPoolin  (8, 6, 6, 32)            0
#  g2D)
#
#  conv2d_44 (Conv2D)          (8, 6, 6, 32)             9248
#
#  max_pooling2d_44 (MaxPoolin  (8, 3, 3, 32)            0
#  g2D)
#
#  dropout_14 (Dropout)        (8, 3, 3, 32)             0
#
#  flatten_14 (Flatten)        (8, 288)                  0
#
#  dense_42 (Dense)            (8, 64)                   18496
#
#  dense_43 (Dense)            (8, 64)                   4160
#
# ...

# %% [markdown]
# ## Plot accuracy and loss of the training process

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

fig = plt.figure(figsize=(15, 7))
ax = plt.gca()

ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy (Line), Loss (Dashes)')

ax.axhline(1, color='gray')

plt.plot(accuracy, color='blue')
plt.plot(val_accuracy, color='orange')
plt.plot(loss, '--', color='blue', alpha=0.5)
plt.plot(val_loss, '--', color='orange', alpha=0.5)

# %%
# let the model make predictions for our training data
y_predictions = model.predict(X_test)

# to build a confusion matrix, we have to convert it to classifications
# this can be done by using the argmax() function to set the probability to 1 and the rest to 0
y_predictions = np.argmax(y_predictions, axis=1)

# create and plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_predictions)

fig = plt.figure(figsize=(10, 10))

ConfusionMatrixDisplay(conf_matrix, display_labels=label_names).plot(ax=plt.gca())

plt.xticks(rotation=90, ha='center')
pass
# Out:
# 4/4 [==============================] - 1s 63ms/step

# %% [markdown]
# ## Summary

# %% [markdown]
# An overview for the performance metrics of the different activation functions of the kernels:
#
# |Funktion|acc|val_acc|loss|val_loss|number of epochs|average time per epoch in s|time for training in s|
# |---|---|---|---|---|---|---|---|
# |Relu|0.9707|0.9141|0.1004|0.2214|16|5,0625|81|
# |Leaky ReLu|0.9570|0.9375|0.1291|0.2145|10|5,2|52|
# |Sigmoid|0.9395|0.9141|0.1632|0.3072|32|5,8438|187|
# |Tanh|0.9746|0.9453|0.0837|0.1663|14|5,9286|83|
# |Linear|0.9766|0.9297|0.0634|0.2055|16|5,125|82|

# %% [markdown]
# The accuracy and validation accuracy is over 0.9 for all functions. The best accuracy for the training data has the linear function (0.9766) but the accuracy for the test set is 0.9297 which is the second highest difference. The highest difference for acc and val_acc has the Relu function (acc: 0.9707/val_acc: 0.9141). This indicates that these two functions tend to have more overfitting for the training data. The highest val_acc has the Tanh function (0.9453) and the lowest the Sigmoid/Relu function (0.9141). The lowest training time was needed for the Leaky ReLu function (52s), the highest for the Sigmoid function (187s) and the other functions had a similar training time with about 82 seconds. The major factor impacting this time was the number of epochs needed, because the time per epoch was between 5 and 6 seconds for all functions.
